# %%
import matplotlib.pyplot as plt

farmer_categories = ['Marginal', 'Small', 'Semi medium', 'Medium', 'Large']
number_of_farmers = [462990, 398200, 250050, 104880, 14110]

plt.bar(farmer_categories, number_of_farmers)
plt.xlabel('Farmer Categories')
plt.ylabel('Number of Farmers')
plt.title('Distribution of Farmers by Land Holding Category')
plt.show()
